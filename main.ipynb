# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.utils import data_ingestor

# %% [markdown]
# # Ingest Achievements

# %%
data_ingestor.ingest_achievements()
# Out:
# Exported achievements to c:\Users\Owner\OneDrive\Desktop\github\team-root-bingo-sheet-generator\data\achievements.json
# {'Faction': {'Cats': {'1': {'name': 'Might Makes Right',
#     'icon': '-cat',
#     'mode': 'Both',
#     'window': 'In a single turn',
#     'base': '`Battle` {x} times as the attacker',
#     'normal': '3',
#     'elite': '5',
#     'notes': None},
#    '26': {'name': 'Monolithic',
#     'icon': '-cat',
#     'mode': 'Normal',
#     'window': 'Simultaneously',
#     'base': 'Have all 6 buildings of a single type built/on the board',
#     'normal': None,
#     'elite': None,
#     'notes': None},
#    '27': {'name': 'Royal Healthcare',
#     'icon': '-cat',
#     'mode': 'Both',
#     'window': 'In a single turn',
#     'base': '`Field Hospital` a total of at least {x} warriors',
#     'normal': '4',
#     'elite': '7',
#     'notes': None},
#    '28': {'name': 'Just Me & My Bodyguards',
#     'icon': '-cat',
#     'mode': 'Both',
# ...
